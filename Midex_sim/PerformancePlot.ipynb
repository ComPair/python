# %%
from matplotlib import *
import numpy as np


import FigureOfMeritPlotter

import EventAnalysis
#data = FigureOfMeritPlotter.parseEventAnalysisLogs(directory="../Simulations/AMEGO4x4PerformancePlotTraFiles/", triggerEfficiencyFilename='../Simulations/AMEGO4x4PerformancePlotTraFiles/TriggerEfficiency.txt')

# %%
EventAnalysis.getTriggerEfficiency(directory='/data/slag2/dtak/PerformancePlotSimFiles/')

# %%
events = EventAnalysis.performCompleteAnalysis('FarFieldPointSource_5.011MeV_Cos1.0.inc1.id1.tra', showPlots=True)

# Calculate the angular resolution measurement (ARM) for Compton events
# Out:
# Files identified for analysis:
# 5.011 MeV Cos 1.0 FarFieldPointSource_5.011MeV_Cos1.0.inc1.id1.tra
#
# Parsing: 5.011 MeV Cos 1.0 FarFieldPointSource_5.011MeV_Cos1.0.inc1.id1.tra
#
# Parsing: FarFieldPointSource_5.011MeV_Cos1.0.inc1.id1.tra
# Progress: 97%
#
# Statistics of Event Selection
# ***********************************
# Total number of analyzed events: 39642
#
# Number of unknown events: 20645 (34%)
# Number of pair events: 450 (0%)
# Number of Compton events: 39192 (65%)
#  - Number of tracked electron events: 18568 (47%)
#  - Number of untracked electron events: 20624 (52%)
#
#
# Calculating the energy resolution for All Compton events...
# EventAnalysis.getEnergyResolutionForComptonEvents(events, numberOfBins=100, energyPlotRange=None, energyFitRange=None)
# 96 96
# /net/slag2/dtak/PerformancePlotSimFiles/EventAnalysis.py:1707: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax0 = plot.subplot(111)
# Statistics of energy histogram and fit (Compton events)
# ***********************************************************
# Compton and pair events in energy histogram: 5500 (13.874173856011302%)
#
# Mean of Guassian fit: 4960.745188254545 keV
# Sigma of Gaussian fit: 61.693001430910904 keV
# FWHM of Guassian fit: 145.27591640763202 keV
#
# Max of asymmetric Guassian fit: 4981.018255 keV
# FWHM of asymmetric Guassian fit: 207.20037000000048 keV
# Calculating the angular resolution measurement for Compton events...
# EventAnalysis.getARMForComptonEvents(events, numberOfBins=100, phiRadius=5)
#
#
# Statistics of ARM histogram and fit (Compton Events)
# ***********************************
# Compton and pair events in ARM histogram: 2109 (30.27997128499641%)
#
# Mean of fit: 0.7531121574393029
# FWHM of fit: 4.995646062297377
# /data/slag2/jsperki1/software/python38/lib/python3.8/site-packages/scipy/optimize/minpack.py:807: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
#
# Calculating the energy resolution for Untracked Compton events...
# EventAnalysis.getEnergyResolutionForComptonEvents(events, numberOfBins=100, energyPlotRange=None, energyFitRange=None)
# 96 96
#
#
# Statistics of energy histogram and fit (Compton events)
# ***********************************************************
# Compton and pair events in energy histogram: 2318 (10.999335674290595%)
#
# Mean of Guassian fit: 4984.91932088007 keV
# Sigma of Gaussian fit: 49.83253393032535 keV
# FWHM of Guassian fit: 117.34664979381505 keV
#
# Max of asymmetric Guassian fit: 4989.9536499999995 keV
# FWHM of asymmetric Guassian fit: 163.45388000000094 keV
# /net/slag2/dtak/PerformancePlotSimFiles/EventAnalysis.py:1707: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax0 = plot.subplot(111)
# Calculating the angular resolution measurement for Untracked Compton events...
# EventAnalysis.getARMForComptonEvents(events, numberOfBins=100, phiRadius=5)
#
#
# Statistics of ARM histogram and fit (Compton Events)
# ***********************************
# Compton and pair events in ARM histogram: 614 (19.838449111470112%)
#
# Mean of fit: 0.30512809087446985
# FWHM of fit: 3.696778086100059
# /data/slag2/jsperki1/software/python38/lib/python3.8/site-packages/scipy/optimize/minpack.py:807: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Calculating the energy resolution for Tracked Compton events...
# EventAnalysis.getEnergyResolutionForComptonEvents(events, numberOfBins=100, energyPlotRange=None, energyFitRange=None)
# 96 96
#
#
# Statistics of energy histogram and fit (Compton events)
# ***********************************************************
# Compton and pair events in energy histogram: 2870 (15.090966452834158%)
#
# Mean of Guassian fit: 4944.155113240417 keV
# Sigma of Gaussian fit: 69.28077096096014 keV
# FWHM of Guassian fit: 163.14374819406706 keV
#
# Max of asymmetric Guassian fit: 4976.5587749999995 keV
# FWHM of asymmetric Guassian fit: 184.6815999999999 keV
# /net/slag2/dtak/PerformancePlotSimFiles/EventAnalysis.py:1707: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax0 = plot.subplot(111)
# Calculating the angular resolution measurement for Tracked Compton events...
# EventAnalysis.getARMForComptonEvents(events, numberOfBins=100, phiRadius=5)
#
#
# Statistics of ARM histogram and fit (Compton Events)
# ***********************************
# Compton and pair events in ARM histogram: 1505 (46.30769230769231%)
#
# Mean of fit: 0.8248178538806017
# FWHM of fit: 4.969100776590681
# /data/slag2/jsperki1/software/python38/lib/python3.8/site-packages/scipy/optimize/minpack.py:807: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Calculating the energy resolution for pair events...
# EventAnalysis.getEnergyResolutionForPairEvents(events, numberOfBins=100)
#
#
# Statistics of energy histogram and fit (pair events)
# ********************************************************
# Number of Compton and pair events in histogram: 450 (100.0%)
#
# Fitting in range:  2155.4217 6466.2651
# Max of fit: 4326.7144499999995 keV
# FWHM of fit: 1079.2314000000006 keV
# sigma of fit: 539.6157000000003 keV
# Calculating the angular resolution measurement for pair events...
# EventAnalysis.getARMForPairEvents(events, numberOfBins=100, showDiagnosticPlots=False)
#
#
# Statistics of ARM histogram and fit (Pair Events)
# *****************************************************
#
# Total number of pair events: 450
# Number of pair events passing quality cut  : 450 (100.0%)
# Number of pair events passing opening angle: 228 (50.666666666666664%)
# Number of pair events included in ARM histogram: 228 (100.0%)
#
# Maximum: 7.0
# 68% containment (data): 15.42 deg
# 68% containment (histogram): 15.45 deg
# Results saved to:
# FarFieldPointSource_5.011MeV_Cos1.0.inc1.id1.log

# %%
triggerEfficiencyFilename ='/data/slag2/dtak/PerformancePlotSimFiles/TriggerEfficiency.txt'

# %%
directory='/data/slag2/dtak/PerformancePlotSimFiles/'

# %%
data = FigureOfMeritPlotter.parseEventAnalysisLogs(directory, triggerEfficiencyFilename=triggerEfficiencyFilename)
# Out:
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_0.158MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_0.316MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_0.501MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_1.000MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_1.584MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_3.162MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_5.011MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_10.000MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_15.848MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_31.622MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_0.158MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_0.316MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_0.501MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_1.000MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_1.584MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_3.162MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_5.011MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_10.000MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_15.848MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_31.622MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_50.118MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_50.118MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_100.000MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_100.000MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_158.489MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_158.489MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_316.227MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_316.227MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_501.187MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_501.187MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_1000.000MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_1000.000MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_1584.893MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_1584.893MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_3162.277MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_3162.277MeV_Cos0.8.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_5011.872MeV_Cos1.0.inc1.id1.log
# Parsing: /data/slag2/dtak/PerformancePlotSimFiles//FarFieldPointSource_5011.872MeV_Cos0.8.inc1.id1.log

# %%
FigureOfMeritPlotter.plotEffectiveArea(data,angleSelections=1.0, ylog=True)
# Out:
# NumberOfReconstructedEvents Pair nan
# NumberOfReconstructedEvents Pair nan
# NumberOfReconstructedEvents Pair nan
# NumberOfReconstructedEvents Pair nan
# NumberOfReconstructedEvents Pair nan
# NumberOfReconstructedEvents Pair 7.0
# NumberOfReconstructedEvents Pair 450.0
# NumberOfReconstructedEvents Pair 4910.0
# NumberOfReconstructedEvents Pair 8880.0
# NumberOfReconstructedEvents Pair 14331.0
# NumberOfReconstructedEvents Pair 17127.0
# NumberOfReconstructedEvents Pair 19732.0
# NumberOfReconstructedEvents Pair 19176.0
# NumberOfReconstructedEvents Pair 16408.0
# NumberOfReconstructedEvents Pair 14119.0
# NumberOfReconstructedEvents Pair 10367.0
# NumberOfReconstructedEvents Pair 7758.0
# NumberOfReconstructedEvents Pair 1940.0
# NumberOfReconstructedEvents Pair 915.0
# EffectiveArea Pair [           nan            nan            nan            nan
#             nan 9.56488993e-02 6.34107984e+00 7.56722012e+01
#  1.48792423e+02 2.76618850e+02 3.61782036e+02 4.80644579e+02
#  5.17310937e+02 5.22221481e+02 5.05353639e+02 4.34634359e+02
#  3.57327861e+02 1.00596564e+02 5.06729533e+01]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:983: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Energy = Energy[i]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:984: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   EffectiveArea_Tracked = EffectiveArea_Tracked[i]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:985: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   EffectiveArea_Untracked = EffectiveArea_Untracked[i]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:986: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   EffectiveArea_Pair = EffectiveArea_Pair[i]
# (array([  1.42382498, 203.90764134, 446.06303725, 499.69833888,
#         404.03363908,          nan,          nan,          nan,
#                  nan,          nan,          nan,          nan,
#                  nan,          nan,          nan,          nan,
#                  nan,          nan,          nan]),
#  array([           nan, 4.04364704e-02, 9.84882645e+00, 9.42452065e+01,
#         1.98962661e+02, 2.89583875e+02, 2.61647045e+02, 1.70023569e+02,
#                    nan,            nan,            nan,            nan,
#                    nan,            nan,            nan,            nan,
#                    nan,            nan,            nan]),
#  array([           nan,            nan,            nan,            nan,
#                    nan, 9.56488993e-02, 6.34107984e+00, 7.56722012e+01,
#         1.48792423e+02, 2.76618850e+02, 3.61782036e+02, 4.80644579e+02,
#         5.17310937e+02, 5.22221481e+02, 5.05353639e+02, 4.34634359e+02,
#         3.57327861e+02, 1.00596564e+02, 5.06729533e+01]),
#  array([1.580000e-01, 3.160000e-01, 5.010000e-01, 1.000000e+00,
#         1.584000e+00, 3.162000e+00, 5.011000e+00, 1.000000e+01,
#         1.584800e+01, 3.162200e+01, 5.011800e+01, 1.000000e+02,
#         1.584890e+02, 3.162270e+02, 5.011870e+02, 1.000000e+03,
#         1.584893e+03, 3.162277e+03, 5.011872e+03]))

# %%
FigureOfMeritPlotter.plotEnergyResolution(data, angleSelections=1.0)
# Out:
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:679: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Energy = Energy[i]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:680: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Sigma_tracked = Sigma_tracked[i]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:681: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Sigma_untracked = Sigma_untracked[i]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:682: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Sigma_pair = Sigma_pair[i]
# (array([1.580000e-01, 3.160000e-01, 5.010000e-01, 1.000000e+00,
#         1.584000e+00, 3.162000e+00, 5.011000e+00, 1.000000e+01,
#         1.584800e+01, 3.162200e+01, 5.011800e+01, 1.000000e+02,
#         1.584890e+02, 3.162270e+02, 5.011870e+02, 1.000000e+03,
#         1.584893e+03, 3.162277e+03, 5.011872e+03]),
#  array([0.05781586, 0.05626712, 0.04911732, 0.04371628, 0.03255961]),
#  array([0.25360107, 0.41225381, 0.60038493, 0.38520391, 0.33682812,
#         0.31966299, 0.30692265, 0.30663562, 0.30147094, 0.2833341 ,
#         0.27990133]))

# %%
FigureOfMeritPlotter.plotAngularResolution(data, angleSelections=1.0)
# Out:
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:412: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Energy = Energy[t]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:413: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   FWHM_tracked = FWHM_tracked[t]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:414: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   FWHM_untracked = FWHM_untracked[t]
# /net/slag2/dtak/PerformancePlotSimFiles/FigureOfMeritPlotter.py:415: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Containment68 = Containment68[t]
# (array([1.580000e-01, 3.160000e-01, 5.010000e-01, 1.000000e+00,
#         1.584000e+00, 3.162000e+00, 5.011000e+00, 1.000000e+01,
#         1.584800e+01, 3.162200e+01, 5.011800e+01, 1.000000e+02,
#         1.584890e+02, 3.162270e+02, 5.011870e+02, 1.000000e+03,
#         1.584893e+03, 3.162277e+03, 5.011872e+03]),
#  array([        nan,         nan, 12.76284152,  6.39703824,  5.19461253,
#          4.74679055,  4.96910078,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan]),
#  array([        nan,         nan,         nan,         nan,         nan,
#                 nan, 15.41562112, 11.59955929,  9.75525107,  6.03412477,
#          4.26524898,  2.79582203,  2.06316627,  1.31882069,  0.98549562,
#          0.7929695 ,  0.69656545,  1.57858844,         nan]))

# %%
from EventAnalysis import *

# %%
numberOfBins=100
onlyTrackedElectrons=False
onlyUntrackedElectrons=True
energyPlotRange=None
energyFitRange=None
showPlots=True
energyHardCut=5
inputEnergy=5.011

# %%
energyFitRange
