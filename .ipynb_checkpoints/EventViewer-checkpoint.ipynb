# %%
import EventViewer

# %%
EventViewer.plot('FarFieldPointSource_1.000MeV_Cos1.0.inc1.id1.sim',  showEvent=3, geometry = 'Amego_Midex')
# Out:
# Showing Trigger: 3
#  - Time: 0.000004279 sec
#  - Simulated event: 287
#  - Initial energy:   1000.000 keV
#  - Total deposited energy in sensitive material: 201.536 keV (20.15%)
#  - Total deposited energy in non-sensitive material: 620.88 keV (62.09%)
#  - Total escaped energy: 177.584 keV (17.76%)
